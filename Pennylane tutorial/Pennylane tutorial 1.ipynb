# %% [markdown]
# # Installing Pennylane

# %%
pip install pennylane --upgrade
# Out:
# Collecting pennylane
#   Obtaining dependency information for pennylane from https://files.pythonhosted.org/packages/75/46/28e20e5fbbdcb821e58fcc1e8550dd6c11a70240fa81250ccd41d670cc7d/PennyLane-0.34.0-py3-none-any.whl.metadata
#   Downloading PennyLane-0.34.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy in c:\users\sidej\anaconda3\lib\site-packages (from pennylane) (1.24.3)
# Requirement already satisfied: scipy in c:\users\sidej\anaconda3\lib\site-packages (from pennylane) (1.11.1)
# Requirement already satisfied: networkx in c:\users\sidej\anaconda3\lib\site-packages (from pennylane) (3.1)
# Collecting rustworkx (from pennylane)
#   Obtaining dependency information for rustworkx from https://files.pythonhosted.org/packages/7d/9b/6792b98bae33c4aba84206c6e928c21738c839a846fe58c959290122c18c/rustworkx-0.14.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading rustworkx-0.14.0-cp311-cp311-win_amd64.whl.metadata (10 kB)
# Collecting autograd (from pennylane)
#   Obtaining dependency information for autograd from https://files.pythonhosted.org/packages/81/70/d5c7c2a458b8be96495c8b1634c2155beab58cbe864b7a9a5c06c2e52520/autograd-1.6.2-py3-none-any.whl.metadata
#   Downloading autograd-1.6.2-py3-none-any.whl.metadata (706 bytes)
# Requirement already satisfied: toml in c:\users\sidej\anaconda3\lib\site-packages (from pennylane) (0.10.2)
# Requirement already satisfied: appdirs in c:\users\sidej\anaconda3\lib\site-packages (from pennylane) (1.4.4)
# Collecting semantic-version>=2.7 (from pennylane)
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting autoray>=0.6.1 (from pennylane)
#   Obtaining dependency information for autoray>=0.6.1 from https://files.pythonhosted.org/packages/ea/23/cd4104e209b29ea11ae9cfdff0d5859121981d59af77249117d6bfd60d0b/autoray-0.6.8-py3-none-any.whl.metadata
#   Downloading autoray-0.6.8-py3-none-any.whl.metadata (5.7 kB)
# Collecting cachetools (from pennylane)
#   Obtaining dependency information for cachetools from https://files.pythonhosted.org/packages/a2/91/2d843adb9fbd911e0da45fbf6f18ca89d07a087c3daa23e955584f90ebf4/cachetools-5.3.2-py3-none-any.whl.metadata
#   Downloading cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pennylane-lightning>=0.34 (from pennylane)
#   Obtaining dependency information for pennylane-lightning>=0.34 from https://files.pythonhosted.org/packages/73/fa/4bcd309807a43ed83cc5d58182d78f8b616e7886de6145163a8ac4fb74ce/PennyLane_Lightning-0.34.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading PennyLane_Lightning-0.34.0-cp311-cp311-win_amd64.whl.metadata (21 kB)
# Requirement already satisfied: requests in c:\users\sidej\anaconda3\lib\site-packages (from pennylane) (2.31.0)
# Requirement already satisfied: typing-extensions in c:\users\sidej\anaconda3\lib\site-packages (from pennylane) (4.7.1)
# Requirement already satisfied: future>=0.15.2 in c:\users\sidej\anaconda3\lib\site-packages (from autograd->pennylane) (0.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sidej\anaconda3\lib\site-packages (from requests->pennylane) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sidej\anaconda3\lib\site-packages (from requests->pennylane) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sidej\anaconda3\lib\site-packages (from requests->pennylane) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sidej\anaconda3\lib\site-packages (from requests->pennylane) (2023.7.22)
# Downloading PennyLane-0.34.0-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.6 MB 10.5 MB/s eta 0:00:01
#    -------------------------- ------------- 1.0/1.6 MB 10.8 MB/s eta 0:00:01
#    ---------------------------------------  1.5/1.6 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 10.0 MB/s eta 0:00:00
# Downloading autoray-0.6.8-py3-none-any.whl (49 kB)
#    ---------------------------------------- 0.0/49.9 kB ? eta -:--:--
#    ---------------------------------------- 49.9/49.9 kB ? eta 0:00:00
# Downloading PennyLane_Lightning-0.34.0-cp311-cp311-win_amd64.whl (5.2 MB)
#    ---------------------------------------- 0.0/5.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/5.2 MB 10.2 MB/s eta 0:00:01
#    ------ --------------------------------- 0.9/5.2 MB 11.0 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.4/5.2 MB 11.2 MB/s eta 0:00:01
#    -------------- ------------------------- 1.9/5.2 MB 11.3 MB/s eta 0:00:01
#    ------------------- -------------------- 2.5/5.2 MB 11.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.0/5.2 MB 11.2 MB/s eta 0:00:01
#    --------------------------- ------------ 3.5/5.2 MB 11.3 MB/s eta 0:00:01
#    ------------------------------- -------- 4.1/5.2 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 4.5/5.2 MB 11.4 MB/s eta 0:00:01
#    ------------------------------------ --- 4.8/5.2 MB 10.5 MB/s eta 0:00:01
#    ---------------------------------------  5.2/5.2 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 5.2/5.2 MB 10.1 MB/s eta 0:00:00
# Downloading autograd-1.6.2-py3-none-any.whl (49 kB)
#    ---------------------------------------- 0.0/49.3 kB ? eta -:--:--
#    ---------------------------------------- 49.3/49.3 kB 2.6 MB/s eta 0:00:00
# Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Downloading rustworkx-0.14.0-cp311-cp311-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.6 MB 11.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.1/1.6 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  1.5/1.6 MB 12.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 11.0 MB/s eta 0:00:00
# Installing collected packages: semantic-version, rustworkx, cachetools, autoray, autograd, pennylane-lightning, pennylane
# Successfully installed autograd-1.6.2 autoray-0.6.8 cachetools-5.3.2 pennylane-0.34.0 pennylane-lightning-0.34.0 rustworkx-0.14.0 semantic-version-2.10.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Tutorial 1
#
# ## Device and Qnode

# %%
import pennylane as qml
from pennylane import numpy as np
import matplotlib.pyplot as plt

# %%
dev = qml.device("default.qubit", wires=2)

# %%
@qml.qnode(dev)
def circuit(theta):
    qml.PauliX(wires = 1)
    qml.CNOT(wires = [1, 0])
    qml.RY(theta, wires = 0)

    return qml.expval(qml.PauliZ(wires = 0))

# %%
print(circuit(np.pi))
# Out:
# 1.0

# %%
thetas = np.arange(0, 2*np.pi, 0.01)
measurements = [circuit(theta) for theta in thetas]
plt.plot(thetas, measurements)
plt.show()
